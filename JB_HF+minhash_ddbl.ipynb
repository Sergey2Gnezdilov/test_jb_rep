# %%
from google.colab import userdata
userdata.get('hf_api')
# Out:
# 'hf_'

# %%
# !pip install datasets huggingface_hub datasketch dpu-utils
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 7.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 14.5 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !wget https://github.com/Sergey2Gnezdilov/test_jb_rep/blob/main/minhash_deduplication.py
# Out:
# --2024-12-11 15:32:10--  https://github.com/Sergey2Gnezdilov/test_jb_rep/blob/main/minhash_deduplication.py
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘minhash_deduplication.py’
#
# minhash_deduplicati     [ <=>                ] 476.77K  --.-KB/s    in 0.06s
#
# 2024-12-11 15:32:10 (7.70 MB/s) - ‘minhash_deduplication.py’ saved [488217]

# %%
# !wget https://github.com/Sergey2Gnezdilov/test_jb_rep/blob/main/near_deduplicate_colab.py
# Out:
# --2024-12-11 15:32:58--  https://github.com/Sergey2Gnezdilov/test_jb_rep/blob/main/near_deduplicate_colab.py
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘near_deduplicate_colab.py’
#
# near_deduplicate_co     [ <=>                ] 386.04K  --.-KB/s    in 0.06s
#
# 2024-12-11 15:32:58 (6.04 MB/s) - ‘near_deduplicate_colab.py’ saved [395301]

# %%
# !ls
# Out:
# minhash_deduplication.py  near_deduplicate_colab.py  sample_data

# %%
# !python near_deduplicate_colab.py  --dataset_name JetBrains/KStack  \
   --org SergGN  --repo_name sg_jb_kstack --out_path ./near_dedup  --text_column content
# Out:
# Setting up the local directory
# Loading the dataset
# README.md: 100% 4.01k/4.01k [00:00<00:00, 30.8MB/s]
# Resolving data files: 100% 24/24 [00:00<00:00, 73.23it/s]
# Resolving data files: 100% 24/24 [00:00<00:00, 54947.21it/s]
# ...
# train-00000-of-00024.parquet:   0% 0.00/175M [00:00<?, ?B/s]
# train-00000-of-00024.parquet:   6% 10.5M/175M [00:00<00:10, 16.5MB/s]
# train-00000-of-00024.parquet:  12% 21.0M/175M [00:01<00:07, 20.9MB/s]
# train-00000-of-00024.parquet:  18% 31.5M/175M [00:01<00:06, 22.8MB/s]
# train-00000-of-00024.parquet:  24% 41.9M/175M [00:01<00:05, 23.9MB/s]
# train-00000-of-00024.parquet:  30% 52.4M/175M [00:02<00:05, 24.3MB/s]
# train-00000-of-00024.parquet:  36% 62.9M/175M [00:02<00:04, 24.7MB/s]
# train-00000-of-00024.parquet:  42% 73.4M/175M [00:03<00:04, 24.9MB/s]
# train-00000-of-00024.parquet:  48% 83.9M/175M [00:03<00:03, 24.8MB/s]
# train-00000-of-00024.parquet:  54% 94.4M/175M [00:03<00:03, 25.0MB/s]
# ...
